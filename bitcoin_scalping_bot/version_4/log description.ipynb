# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torchsummary
from utils import pnl_graph, action_graph, reward_graph
print("hi")
# Out:
# hi

# %%
import os
os.chdir("C:\\Users\\user\\Documents\\GitHub\\crypto-scalping-RL-Agent")
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  'bitcoin_scalping_bot',
#  'data',
#  'README.md',
#  '강화학습을 이용한 단타매매 봇.pdf']

# %%
log = 80

pnl_graph(log), action_graph(log),  reward_graph(log)
# Out:
# (None, None, None)
